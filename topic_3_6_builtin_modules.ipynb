# %% [markdown]
# # Тема 3.6. Обзор некоторых встроенных модулей
#
# ## Задание 1
#
# Импортируйте модуль `math`, вычислите и выведите в консоль абсолютное значение чисел `2.0` и `-2.0`.

# %%
import math

print(math.fabs(2.0))
print(math.fabs(-2.0))
